# %% [raw]
# Recap of the in-class exercises to do:
# (1) Document 2.  --> python survey
# (2) Document 3. --> chance precision of dataframes
# (3) docuyment 3 --> boolean operations with dataframes
# (4) docuemnt 3 --> visualising bicycle counts
# (5) document 3 --> in-class exercises 1-4

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# # 2. In-Class Exercises

# %% [markdown]
# Analize the data of the JetBrains 2017 Python survey https://www.jetbrains.com/research/python-developers-survey-2017/
#
# * Download raw data from http://jb.gg/pythondevsurvey2017raw
# * Read it in pandas
# * Visualize the dataset
# * Select by label and position
# * Drop missing data (NA values)
# * Reproduce "What do you use Python for the most? (single answer)" chart

# %%
pydata = pd.read_csv('/users/laurencewilliams/downloads/pythondevsurvey2017_raw_data (1).csv')
pydata.head()
# Out:
#   Is Python the main language you use for your current projects?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3     No, I don’t use Python for my current projects
# 4                                                Yes
#
#   None:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Java:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                    Java
#
#   JavaScript:What other language(s) do you use?  \
# 0                                    JavaScript
# ...

# %%
pydata.dropna(how = 'all')
# Out:
#      Is Python the main language you use for your current projects?  \
# 0                                                   Yes
# 1                                                   Yes
# 2                                                   Yes
# 3        No, I don’t use Python for my current projects
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7        No, I don’t use Python for my current projects
# 8                                                   Yes
# 9                                                   Yes
# 10                                                  Yes
# 11                                                  Yes
# 12             No, I use Python as a secondary language
# 13                                                  Yes
# 14       No, I don’t use Python for my current projects
# ...

# %%
#Reproduce "What do you use Python for the most? (single answer)" chart

pydata['Is Python the main language you use for your current projects?'].value_counts().plot.bar()

# %% [markdown]
# # 3. In-Class Exercises

# %% [markdown]
# With DataFrame (df), do the following:
#
# *   Change precision to 4 decimals
# *   **Where** data is less than zero, set it to NaN
# *   **Where** data is less than 0.5. Set it to 0
# *   **Filter** the rows by the appearance of 0 in column B

# %%
dates = pd.date_range('20191208', periods=6)
dates

df = pd.DataFrame(np.random.randn(6, 5), index=dates, columns=list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2019-12-08  0.455732 -0.696677  0.409302  0.946429  0.222272
# 2019-12-09  0.411207  1.735169  1.497129 -0.651016  1.049444
# 2019-12-10  0.365473  1.234893 -0.179089  0.236928  0.810016
# 2019-12-11 -1.237140 -0.040231 -1.673963 -0.152593 -0.658549
# 2019-12-12  0.151828 -0.766073 -0.426530 -0.189863 -0.702213
# 2019-12-13  0.345880  0.683304 -0.087920 -0.069694  0.228672

# %%
df[df>0]
# Out:
#                    A         B         C         D         E
# 2019-12-08  0.455732       NaN  0.409302  0.946429  0.222272
# 2019-12-09  0.411207  1.735169  1.497129       NaN  1.049444
# 2019-12-10  0.365473  1.234893       NaN  0.236928  0.810016
# 2019-12-11       NaN       NaN       NaN       NaN       NaN
# 2019-12-12  0.151828       NaN       NaN       NaN       NaN
# 2019-12-13  0.345880  0.683304       NaN       NaN  0.228672

# %%
df[df<0.5] = 0
df
df1 = df.copy()
df1
# Out:
#               A         B         C         D         E
# 2019-12-08  0.0  0.000000  0.000000  0.946429  0.000000
# 2019-12-09  0.0  1.735169  1.497129  0.000000  1.049444
# 2019-12-10  0.0  1.234893  0.000000  0.000000  0.810016
# 2019-12-11  0.0  0.000000  0.000000  0.000000  0.000000
# 2019-12-12  0.0  0.000000  0.000000  0.000000  0.000000
# 2019-12-13  0.0  0.683304  0.000000  0.000000  0.000000

# %%
df[df['B']].isin(list(0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-bc95f855b146> in <module>()
# ----> 1 df[df['B']].isin(list(0))
#
# /Users/laurencewilliams/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /Users/laurencewilliams/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
# ...

# %% [markdown]
# # Example: Visualizing Seattle Bicycle Counts

# %% [markdown]
# As a more involved example of working with some time series data, let's take a look at bicycle counts on Seattle's [Fremont Bridge](http://www.openstreetmap.org/#map=17/47.64813/-122.34965).
# This data comes from an automated bicycle counter, installed in late 2012, which has inductive sensors on the east and west sidewalks of the bridge.
# The hourly bicycle counts can be downloaded from http://data.seattle.gov/; here is the [direct link to the dataset](https://data.seattle.gov/Transportation/Fremont-Bridge-Hourly-Bicycle-Counts-by-Month-Octo/65db-xm6k).
#
# As 3/10/2019, the CSV can be downloaded as follows:

# %%
# !curl -o FremontBridge.csv https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD

# %% [markdown]
# # Cleaning data. Small example

# %%
service_reqs = pd.read_csv("https://github.com/vfp1/bts-mbds-data-science-foundations-209/raw/master/sessions/data/311-service-requests.csv", low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-321bba77b00d> in <module>()
# ----> 1 service_reqs = pd.read_csv("https://github.com/vfp1/bts-mbds-data-science-foundations-209/raw/master/sessions/data/311-service-requests.csv", low_memory=False)
#
# ...
